# %%
import pandas as pd

# %%
# loading the dataset

df = pd.read_csv('FoodBalanceSheets_E_Africa_NOFLAG.csv', encoding='latin1')
df.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
#6

m_s = df[(df['Area'] == 'Madagascar') & (df['Element'] == 'Protein supply quantity (g/capita/day)')]
m_s['Y2015'].sum()
# Out:
# 173.04999999999998

# %%
#7

round(df.describe()['Y2017'][['mean', 'std']],2)
# Out:
# mean     140.92
# std     1671.86
# Name: Y2017, dtype: float64

# %%
#8

df.corr()['Element Code'].sort_values()
# Out:
# Item Code      -0.024683
# Area Code      -0.000209
# Y2016           0.023444
# Y2015           0.023889
# Y2017           0.024254
# Y2018           0.024279
# Y2014           0.024457
# Element Code    1.000000
# Name: Element Code, dtype: float64

# %%
#10

df.groupby('Element').sum()['Y2017']['Processing']
# Out:
# 292836.0

# %%
#12

print(df['Y2014'].isnull().value_counts())
print()
print(df['Y2014'].isnull().value_counts(normalize=True))
# Out:
# False    59354
# True      1589
# Name: Y2014, dtype: int64
#
# False    0.973926
# True     0.026074
# Name: Y2014, dtype: float64

# %%
#13

df[['Y2017', 'Area']].groupby('Area').sum().sort_values(by='Y2017', ascending=False)
# Out:
#                                   Y2017
# Area
# Nigeria                      1483268.23
# Egypt                         866379.92
# South Africa                  517590.54
# Ethiopia                      448683.76
# Morocco                       388495.36
# Ghana                         337599.06
# Algeria                       325644.27
# United Republic of Tanzania   322616.85
# Kenya                         264660.66
# Sudan                         239931.92
# Cameroon                      232030.43
# Angola                        229159.57
# Côte d'Ivoire                 224599.01
# Uganda                        213950.38
# Malawi                        181098.71
# Mozambique                    161407.98
# Mauritania                    156665.46
# Mali                          149928.33
# Madagascar                    131197.73
# Niger                         126707.58
# Benin                         124771.22
# Tunisia                       124167.20
# ...

# %%
#14

q14 = df.groupby('Element').sum().reset_index()
q14 [q14['Element'] == 'Stock Variation']
# Out:
#             Element  Area Code  Item Code  Element Code     Y2014     Y2015  \
# 15  Stock Variation     571566   11329527      21464704  58749.83  34910.99
#
#        Y2016     Y2017     Y2018
# 15  33140.12  54316.91  20577.91

# %%
#15

df[['Y2017', 'Area']].groupby('Area').sum().sort_values(by='Y2017').reset_index()
# Out:
#                            Area       Y2017
# 0                Sudan (former)        0.00
# 1                  Ethiopia PDR        0.00
# 2                       Comoros       59.84
# 3                    Seychelles      442.34
# 4         Sao Tome and Principe    12662.63
# 5                    Cabo Verde    14650.74
# 6                 Guinea-Bissau    19102.77
# 7                       Lesotho    21267.96
# 8                      Botswana    22101.30
# 9                      Djibouti    22729.91
# 10                       Gambia    23154.18
# 11                        Gabon    27979.64
# 12                      Liberia    29342.20
# 13                      Namibia    29874.89
# 14     Central African Republic    29937.00
# 15                        Congo    41181.68
# 16                         Togo    49841.88
# 17                    Mauritius    51114.83
# 18                     Eswatini    54343.33
# 19                 Sierra Leone    55311.33
# ...

# %%
#16

df.groupby('Item').sum()[['Y2015', 'Y2018']]
# Out:
#                          Y2015      Y2018
# Item
# Alcohol, Non-Food      2180.00    2293.00
# Alcoholic Beverages   98783.72   97847.27
# Animal Products       11811.73   11578.61
# Animal fats          200675.72  269648.27
# Apples and products   10559.15    9640.51
# ...                        ...        ...
# Vegetables, Other    158104.08  163987.21
# Vegetal Products     107064.17  107775.39
# Wheat and products   234710.51  242645.19
# Wine                   4251.81    4039.32
# Yams                 203151.78  221272.09
#
# [119 rows x 2 columns]

# %%
#19

df['Area'].nunique()
# Out:
# 49
